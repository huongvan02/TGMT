# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'D:/Image_TGMT/img04.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x339>

# %%
rotated_img = img.rotate(90)
display(rotated_img)
# Out:
# <PIL.Image.Image image mode=RGB size=450x339>

# %%
rotated_img = rotated_img.rotate(90)
display(rotated_img)
# Out:
# <PIL.Image.Image image mode=RGB size=450x339>

# %%
transposed_img = img.transpose(Image.Transpose.ROTATE_180)
display(transposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=450x339>

# %%
transposed_img = transposed_img.transpose(Image.Transpose.ROTATE_90)
display(transposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=339x450>
