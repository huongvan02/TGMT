# %%
#!pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
my_path = 'D:/Image_TGMT/img01.jpg'
img = Image.open(my_path)
plt.imshow(img)

# %%
x = [2, 4, 6, 8, 10]
y = [40, 20, 60, 100, 80]
plt.plot(x, y)
plt.show()

# %%
x = [2, 4, 6, 8, 10]
y = [40, 20, 60, 100, 80]
plt.plot(x, y, color = 'green')
plt.show()

# %%
x = [2, 4, 6, 8, 10]
y = [40, 20, 60, 100, 80]
plt.plot(x, y, color = 'green')
plt.title('Ví dụ về biểu đồ')
plt.show()

# %%
x = [2, 4, 6, 8, 10]
y = [40, 20, 60, 100, 80]
plt.plot(x, y, color = 'green')
plt.title('Ví dụ về biểu đồ')
plt.axis('off')
plt.show()

# %%
x = [100, 200, 500, 700]
y = [300, 100, 200, 50]
plt.imshow(img)
plt.plot(x, y, 'yo:')
plt.show()
