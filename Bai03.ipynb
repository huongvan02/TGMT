# %%
from PIL import Image
from imgtools import *

# %%
dir = "D:/Image_TGMT/img04.jpg"

# %%
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x339>

# %%
print(img.size)
# Out:
# (450, 339)

# %%
new_size = (900, 678)
new_img = img.resize(new_size)
display(new_img)
new_img.save('D:/Image_TGMT/img04_resize.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=900x678>

# %%
thumbnail_size = (225, 169)
img.thumbnail(thumbnail_size)
display(img)
img.save('D:/Image_TGMT/img04_thumb.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x169>
