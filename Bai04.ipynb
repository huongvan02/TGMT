# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'D:/Image_TGMT/img03.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533>

# %%
crop_position = (290, 120, 550, 330)
cropped_img = img.crop(crop_position)
display(cropped_img)
# Out:
# <PIL.Image.Image image mode=RGB size=260x210>

# %%
paste_position = (0, 300)
img.paste(cropped_img, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533>
