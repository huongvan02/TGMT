# %%
from PIL import Image

# %%
dir = 'D:/Image_TGMT'

# %%
image_path = dir + '/img01.jpg'
print(image_path)
# Out:
# D:/Image_TGMT/img01.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %%
print('Định dạng ảnh: ', img01.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
print('Kích thước ảnh: ', img01.size)
# Out:
# Kích thước ảnh:  (736, 414)

# %%
new_img_01_path = dir + '/new_01_rename.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)
