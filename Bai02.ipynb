# %%
from PIL import Image
from imgtools import *

# %%
dir = 'D:/Image_TGMT'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (736, 414)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>
# (400, 600)
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=400x600>
# (800, 533)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533>
# (450, 339)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x339>
# (612, 612)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x612>
